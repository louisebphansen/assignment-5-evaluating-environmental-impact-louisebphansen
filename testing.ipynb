# %%
pip install pandas codecarbon matplotlib torch transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 2.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 47.8 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.6/174.6 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 36.4 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 7.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 10.2 MB/s eta 0:00:0000:0100:01
# ...

# %%
import pandas as pd 
from codecarbon import EmissionsTracker
import os
import matplotlib.pyplot as plt

# %%
# logistic regression script
log_tasks = pd.read_csv('../assignment-2-text-classification-louisebphansen/emissions/emissions_base_3310d499-c2cb-4ea3-aa32-457db999bb9f.csv')
log_df = pd.read_csv('../assignment-2-text-classification-louisebphansen/emissions/emissions_logistic_regression.csv')
log_full = pd.read_csv('../assignment-2-text-classification-louisebphansen/emissions/emissions_logistic_regression_FULL.csv')

# %%
# neural network script
nn_tasks = pd.read_csv('../assignment-2-text-classification-louisebphansen/emissions/emissions_base_83e4ac13-564c-4b8e-bda5-9d36a20663ff.csv')
nn_df = pd.read_csv('../assignment-2-text-classification-louisebphansen/emissions/emissions_neural_network.csv')
nn_full = pd.read_csv('../assignment-2-text-classification-louisebphansen/emissions/emissions_neural_network_FULL.csv')

# %%
# vectorize script

vect_tasks = pd.read_csv('../assignment-2-text-classification-louisebphansen/emissions/emissions_base_c6a85516-1e67-43e0-b74c-8f8d5378efcb.csv')
vect_df = pd.read_csv('../assignment-2-text-classification-louisebphansen/emissions/emissions_vectorize.csv')
vect_full = pd.read_csv('../assignment-2-text-classification-louisebphansen/emissions/emissions_vectorize_FULL.csv')

# %%
all_tasks = pd.concat([vect_tasks, log_tasks, nn_tasks])

# %%
all_tasks
# Out:
#         task_name            timestamp  \
# 0  Vectorize data  2024-04-29T15:40:30
# 0   Model Fitting  2024-04-29T15:40:44
# 1      Predicting  2024-04-29T15:40:44
# 0   Model Fitting  2024-04-29T16:10:41
# 1      Predicting  2024-04-29T16:10:41
#
#                                project_name  \
# 0            assignment2_vectorize_subtasks
# 0  assignment2_logistic_regression_subtasks
# 1  assignment2_logistic_regression_subtasks
# 0       assignment2_neural_network_subtasks
# 1       assignment2_neural_network_subtasks
#
#                                  run_id    duration     emissions  \
# 0  c6a85516-1e67-43e0-b74c-8f8d5378efcb   36.006721  3.314905e-04
# 0  3310d499-c2cb-4ea3-aa32-457db999bb9f    0.126136  1.161171e-06
# 1  3310d499-c2cb-4ea3-aa32-457db999bb9f    0.005389  2.933787e-08
# 0  83e4ac13-564c-4b8e-bda5-9d36a20663ff  706.923704  6.507380e-03
# 1  83e4ac13-564c-4b8e-bda5-9d36a20663ff    0.033964  2.832912e-07
#
# ...

# %%
all_tasks['task_name'].iloc[1] = 'Fitting logistic regression model'
# Out:
# /tmp/ipykernel_286/3963330182.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   all_tasks['task_name'].iloc[1] = 'Fitting logistic regression model'
# /tmp/ipykernel_286/3963330182.py:1: SettingWithCopyWarning:
# ...

# %%
ass3_full = pd.read_csv('../assignment-3-query-word-embeddings-louisebphansen/emissions/emissions_FULL.csv')

# %%
ass2_emissions = sum(list(vect_full['emissions']) + list(log_full['emissions']) + list(nn_full['emissions']))

# %%
data = {'Assignment 2': ass2_emissions,
        'Assignment 3': (ass3_full['emissions'].tolist()[0])}

# %%
data
# Out:
# {'Assignment 2': 0.013194830925803024, 'Assignment 3': 0.0001635075420236}

# %%
values = list(data.values())

# %%
names = list(data.keys())

# %%
values
# Out:
# [0.013194830925803024, 0.0001635075420236]

# %%
plt.bar(names, values, color = ['green', 'blue'])
plt.ylabel('Emissions of CO₂eq in kilograms')
plt.title('Emissions of CO₂eq across assignments')
# Out:
# Text(0.5, 1.0, 'Emissions of CO₂eq across assignments')

# %% [markdown]
# ## Comparing CO₂eq emissions across assignments

# %% [markdown]
# In order to compare CO₂eq across assignments, the emission-csv files containing data of running the *entire* analysis for each assignment needs to be loaded:

# %%
folder_path = os.path.join('..')

# %%
# loading data for assignment 1

assignment1_full = pd.read_csv(...)
assignment1_full.head()

# %% [markdown]
# Assignment 2 consists of three seperate scripts, which runs a vectorizer on a dataset, a logistic regression and a neural network. So, in order to get the full CO₂eq emissions for this assignment, we need to add the emissions from running the three scripts together:

# %%
# fix paths!
vect_full = pd.read_csv('../assignment-2-text-classification-louisebphansen/emissions/emissions_vectorize_FULL.csv')
log_full = pd.read_csv('../assignment-2-text-classification-louisebphansen/emissions/emissions_logistic_regression_FULL.csv')
nn_full = pd.read_csv('../assignment-2-text-classification-louisebphansen/emissions/emissions_neural_network_FULL.csv')

# %%
# get single value of emissions for assignment 2
assignment2_emissions = sum(list(vect_full['emissions']) + list(log_full['emissions']) + list(nn_full['emissions']))

# %%
# loading data for assignment 3
assignment3_full = pd.read_csv('../assignment-3-query-word-embeddings-louisebphansen/emissions/emissions_FULL.csv')
assignment3_full.head()

# %%
# loading data for assignment 4 (emissions also needs to be added here )
assignment3_full = pd.read_csv('../assignment-3-query-word-embeddings-louisebphansen/emissions/emissions_FULL.csv')
assignment3_full.head()

# %% [markdown]
# ## Compare subtasks for each assignment

# %% [markdown]
# #### Assignment 1

# %% [markdown]
# #### Assignment 2

# %% [markdown]
# #### Assignment 3

# %%
assignment3_subtasks = pd.read_csv('../assignment-3-query-word-embeddings-louisebphansen/emissions/emissions_base_6f96bf03-fd6c-44e2-a7e4-4da95e743941.csv')

# %%
assignment3_subtasks
# Out:
#                        task_name            timestamp          project_name  \
# 0         Model and data loading  2024-04-29T19:30:13  assignment3_subtasks
# 1  Filter df and preprocess test  2024-04-29T19:30:13  assignment3_subtasks
# 2                   Query search  2024-04-29T19:30:13  assignment3_subtasks
#
#                                  run_id   duration     emissions  \
# 0  6f96bf03-fd6c-44e2-a7e4-4da95e743941  16.981869  1.563381e-04
# 1  6f96bf03-fd6c-44e2-a7e4-4da95e743941   0.010278  9.358820e-08
# 2  6f96bf03-fd6c-44e2-a7e4-4da95e743941   0.657558  6.049165e-06
#
#    emissions_rate  cpu_power  gpu_power   ram_power  ...  codecarbon_version  \
# 0        0.000009       42.5        0.0  141.200752  ...               2.3.5
# 1        0.000009       42.5        0.0  141.200752  ...               2.3.5
# 2        0.000009       42.5        0.0  141.200752  ...               2.3.5
#
#    cpu_count                                 cpu_model  gpu_count gpu_model  \
# ...

# %%
def plot_emissions_subtasks(subtasks_df, assignment_number):

    names = list(subtasks_df['task_name'])
    emissions = list(subtasks_df['emissions'])

    # create plot
    fig, ax = plt.subplots(figsize = (8,4))
    ax.bar(names, emissions)
    ax.set_ylabel('Emissions of CO₂eq in kilograms')
    ax.set_title(f'Emissions of CO₂eq for tasks in Assignment {assignment_number}')
    fig.show()

    # also save to file ?

# %%
plot_emissions_subtasks(assignment3_subtasks, 3)

# %%
plot_emissions_subtasks(all_tasks, 2)

# %%
names = list(assignment3_subtasks['task_name'])
emissions = list(assignment3_subtasks['emissions'])

fig, ax = plt.subplots(figsize = (8,4))
ax.bar(names, emissions)
ax.set_ylabel('Kilograms of CO₂eq')
ax.set_title('Emissions of CO₂eq for tasks in Assignment 3')

# %%
all_tasks['assignment'] = 2
assignment3_subtasks['assignment'] = 3

gathered = pd.concat([all_tasks, assignment3_subtasks])

# %%
plot_emissions_subtasks(gathered, '1-4')

# %%
names = list(gathered['task_name'])
emissions = list(gathered['emissions'])

# create plot
fig, ax = plt.subplots(figsize = (6,4))
ax.bar(names, emissions)
ax.set_ylabel('Emissions of CO₂eq in kilograms')
ax.set_title('Emissions of CO₂eq for tasks in all assignments')
ax.tick_params(axis='x', labelrotation=80)
fig.show()

# %%
gathered
# Out:
#                            task_name            timestamp  \
# 0                     Vectorize data  2024-04-29T15:40:30
# 0  Fitting logistic regression model  2024-04-29T15:40:44
# 1                         Predicting  2024-04-29T15:40:44
# 0                      Model Fitting  2024-04-29T16:10:41
# 1                         Predicting  2024-04-29T16:10:41
# 0             Model and data loading  2024-04-29T19:30:13
# 1      Filter df and preprocess test  2024-04-29T19:30:13
# 2                       Query search  2024-04-29T19:30:13
#
#                                project_name  \
# 0            assignment2_vectorize_subtasks
# 0  assignment2_logistic_regression_subtasks
# 1  assignment2_logistic_regression_subtasks
# 0       assignment2_neural_network_subtasks
# 1       assignment2_neural_network_subtasks
# 0                      assignment3_subtasks
# 1                      assignment3_subtasks
# 2                      assignment3_subtasks
#
# ...
