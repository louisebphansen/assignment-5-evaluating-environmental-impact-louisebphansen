# %%
pip install pandas codecarbon matplotlib torch transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 43.9 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.9/494.9 kB 12.8 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 40.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 5.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 8.0 MB/s eta 0:00:00:00:0100:01
# ...

# %%
import pandas as pd 
from codecarbon import EmissionsTracker
import os
import matplotlib.pyplot as plt

# %%
# logistic regression script
vect_tasks = pd.read_csv('../assignment-2-text-classification-louisebphansen/emissions/emissions_base_4b175820-76a2-4f49-880d-ee71d2aaa6a6.csv')
log_tasks = pd.read_csv('../assignment-2-text-classification-louisebphansen/emissions/emissions_base_aaa7262f-e456-45d9-855b-32588ab3c219.csv')
nn_tasks = pd.read_csv('../assignment-2-text-classification-louisebphansen/emissions/emissions_base_95ff4f67-42ac-4865-b441-8e1a99acf763.csv')

# %%
all_tasks = pd.concat([vect_tasks, log_tasks, nn_tasks])

# %%
all_tasks
# Out:
#                       task_name            timestamp  \
# 0              Vectorizing data  2024-05-01T12:51:23
# 0        Fitting logistic model  2024-05-01T12:51:36
# 1  Predict using logistic model  2024-05-01T12:51:36
# 0            Fit neural network  2024-05-01T13:13:13
# 1  Predict using neural network  2024-05-01T13:13:13
#
#                                project_name  \
# 0            assignment2_vectorize_subtasks
# 0  assignment2_logistic_regression_subtasks
# 1  assignment2_logistic_regression_subtasks
# 0       assignment2_neural_network_subtasks
# 1       assignment2_neural_network_subtasks
#
#                                  run_id     duration     emissions  \
# 0  4b175820-76a2-4f49-880d-ee71d2aaa6a6    21.917012  2.017402e-04
# 0  aaa7262f-e456-45d9-855b-32588ab3c219     0.074433  6.962787e-07
# 1  aaa7262f-e456-45d9-855b-32588ab3c219     0.002931  2.337763e-08
# 0  95ff4f67-42ac-4865-b441-8e1a99acf763  1284.228063  1.182301e-02
# ...

# %%
ass2_path = os.path.join('emissions', 'assignment2')

sorted(os.listdir(ass1_path))
# Out:
# ['assignment1_FULL_emissions.csv',
#  'assignment1_subtasks_emissions.csv',
#  'assignment1_subtasks_meta.csv']

# %%
def emissions_and_time(folder, csv_ext):
    
    files = []

    for csv_file in sorted(os.listdir(folder)):
        if csv_file.endswith(csv_ext):
            files.append(csv_file)
    
    full_df = pd.DataFrame()
    
    for file in files:
        df = pd.read_csv(os.path.join(folder, file))
        full_df = pd.concat([full_df, df])
    
    emissions = full_df['emissions'].sum()
    duration = full_df['duration'].sum()
    
    return emissions, duration

# %%
subtasks_emissions, subtasks_duration = total_emissions_and_time(ass2_path, 'subtasks_emissions.csv')

# %%
emissions, duration = total_emissions_and_time(ass2_path)

# %% [markdown]
# ## Comparing CO₂eq emissions across assignments

# %% [markdown]
# In order to compare CO₂eq across assignments, the emission-csv files containing data of running the *entire* analysis for each assignment needs to be loaded:

# %%
# loading data for assignment 1
assignment1_path = os.path.join('emissions', 'assignment1')
assignment1_total_emissions, assignment1_total_duration = emissions_and_time(assignment1_path, 'FULL_emissions.csv')

# %%
# loading data for assignment 2
assignment2_path = os.path.join('emissions', 'assignment2')
assignment2_total_emissions, assignment2_total_duration = emissions_and_time(assignment2_path, 'FULL_emissions.csv')

# %%
# loading data for assignment 2
assignment3_path = os.path.join('emissions', 'assignment3')
assignment3_total_emissions, assignment3_total_duration = emissions_and_time(assignment3_path, 'FULL_emissions.csv')

# %%
# loading data for assignment 2
assignment4_path = os.path.join('emissions', 'assignment4')
assignment4_total_emissions, assignment4_total_duration = emissions_and_time(assignment4_path, 'FULL_emissions.csv')

# %%
total_emissions_data = {'Assignment 1': assignment1_total_emissions,
        'Assignment 2': assignment2_total_emissions,
        'Assignment 3': assignment3_total_emissions,
        'Assignment 4': assignment4_total_emissions}

total_duration_data = {'Assignment 1': assignment1_total_duration,
        'Assignment 2': assignment2_total_duration,
        'Assignment 3': assignment3_total_duration,
        'Assignment 4': assignment4_total_duration}

# %%
total_emissions = list(total_emissions_data.values())
total_durations = list(total_duration_data.values())
assignments = list(total_emissions_data.keys())

# %% [markdown]
# #### Plotting the CO₂eq emissions of all assignments

# %%
plt.bar(assignments, total_emissions, color = ['green', 'blue', 'red', 'orange'])
plt.ylabel('Emissions of CO₂eq in kilograms')
plt.title('Emissions of CO₂eq across assignments')
# Out:
# Text(0.5, 1.0, 'Emissions of CO₂eq across assignments')

# %%
plt.bar(assignments, total_durations, color = ['green', 'blue', 'red', 'orange'])
plt.ylabel('Duration (in seconds)')
plt.title('Duration of running scripts across assignments')
# Out:
# Text(0.5, 1.0, 'Duration of running scripts across assignments')

# %% [markdown]
# ## Compare subtasks for each assignment

# %% [markdown]
# In order to compare the subtasks for each assignment, we need to load the csv files that contain information about the subtask emissions

# %%
def plot_emissions_subtasks(subtasks_df, assignment_number):

    names = list(subtasks_df['task_name'])
    emissions = list(subtasks_df['emissions'])

    # create plot
    fig, ax = plt.subplots(figsize = (8,4))
    ax.bar(names, emissions)
    ax.set_ylabel('Emissions of CO₂eq in kilograms')
    ax.set_title(f'Emissions of CO₂eq for tasks in Assignment {assignment_number}')
    ax.tick_params(axis='x', labelrotation=80)
    fig.show()

    # also save to file ?

# %% [markdown]
# #### Assignment 1

# %%
assignment1_subtasks_emissions, assignment1_subtasks_duration = emissions_and_time(assignment1_path, 'subtasks_emissions.csv')

# %% [markdown]
# #### Assignment 2

# %% [markdown]
# #### Assignment 3

# %%
assignment3_subtasks = pd.read_csv('../assignment-3-query-word-embeddings-louisebphansen/emissions/emissions_base_6f96bf03-fd6c-44e2-a7e4-4da95e743941.csv')

# %%
assignment3_subtasks
# Out:
#                        task_name            timestamp          project_name  \
# 0         Model and data loading  2024-04-29T19:30:13  assignment3_subtasks
# 1  Filter df and preprocess test  2024-04-29T19:30:13  assignment3_subtasks
# 2                   Query search  2024-04-29T19:30:13  assignment3_subtasks
#
#                                  run_id   duration     emissions  \
# 0  6f96bf03-fd6c-44e2-a7e4-4da95e743941  16.981869  1.563381e-04
# 1  6f96bf03-fd6c-44e2-a7e4-4da95e743941   0.010278  9.358820e-08
# 2  6f96bf03-fd6c-44e2-a7e4-4da95e743941   0.657558  6.049165e-06
#
#    emissions_rate  cpu_power  gpu_power   ram_power  ...  codecarbon_version  \
# 0        0.000009       42.5        0.0  141.200752  ...               2.3.5
# 1        0.000009       42.5        0.0  141.200752  ...               2.3.5
# 2        0.000009       42.5        0.0  141.200752  ...               2.3.5
#
#    cpu_count                                 cpu_model  gpu_count gpu_model  \
# ...

# %%
def plot_emissions_subtasks(subtasks_df, assignment_number):

    names = list(subtasks_df['task_name'])
    emissions = list(subtasks_df['emissions'])

    # create plot
    fig, ax = plt.subplots(figsize = (8,4))
    ax.bar(names, emissions)
    ax.set_ylabel('Emissions of CO₂eq in kilograms')
    ax.set_title(f'Emissions of CO₂eq for tasks in Assignment {assignment_number}')
    ax.tick_params(axis='x', labelrotation=80)
    fig.show()

    # also save to file ?

# %%
plot_emissions_subtasks(assignment3_subtasks, 3)

# %%
plot_emissions_subtasks(all_tasks, 2)

# %%
plot_emissions_subtasks(all_tasks, 2)

# %%
names = list(assignment3_subtasks['task_name'])
emissions = list(assignment3_subtasks['emissions'])

fig, ax = plt.subplots(figsize = (8,4))
ax.bar(names, emissions)
ax.set_ylabel('Kilograms of CO₂eq')
ax.set_title('Emissions of CO₂eq for tasks in Assignment 3')

# %%
all_tasks['assignment'] = 2
assignment3_subtasks['assignment'] = 3

gathered = pd.concat([all_tasks, assignment3_subtasks])

# %%
plot_emissions_subtasks(gathered, '1-4')

# %%
names = list(gathered['task_name'])
emissions = list(gathered['emissions'])

# create plot
fig, ax = plt.subplots(figsize = (6,4))
ax.bar(names, emissions, color = )
ax.set_ylabel('Emissions of CO₂eq in kilograms')
ax.set_title('Emissions of CO₂eq for tasks in all assignments')
ax.tick_params(axis='x', labelrotation=80)
fig.show()

# %%
gathered
# Out:
#                            task_name            timestamp  \
# 0                     Vectorize data  2024-04-29T15:40:30
# 0  Fitting logistic regression model  2024-04-29T15:40:44
# 1                         Predicting  2024-04-29T15:40:44
# 0                      Model Fitting  2024-04-29T16:10:41
# 1                         Predicting  2024-04-29T16:10:41
# 0             Model and data loading  2024-04-29T19:30:13
# 1      Filter df and preprocess test  2024-04-29T19:30:13
# 2                       Query search  2024-04-29T19:30:13
#
#                                project_name  \
# 0            assignment2_vectorize_subtasks
# 0  assignment2_logistic_regression_subtasks
# 1  assignment2_logistic_regression_subtasks
# 0       assignment2_neural_network_subtasks
# 1       assignment2_neural_network_subtasks
# 0                      assignment3_subtasks
# 1                      assignment3_subtasks
# 2                      assignment3_subtasks
#
# ...
